# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#pd. set_option('display.max_columns', None)
#pd. set_option('display.max_rows', None)

# %%
df1 = pd.read_csv("../../files/csv/basicinfo-nolabel.csv")

# %%
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %%
df2 = pd.read_csv("../../files/csv/lyricsenhanced.csv")

# %%
df2 = df2[['id', 'lang']]

# %%
df = pd.merge(df1, df2, how='left', on=['id'],
                         sort=False)

# %%
df
# Out:
#         id                             artist             title  year  month  \
# 0        1              Kollegah & Farid Bang   One Night Stand  2018      1
# 1        2                              Bausa               FML  2018      1
# 2        3                               Jazn            Bombay  2018      1
# 3        4                         Tom Walker  Leave A Light On  2018      1
# 4        5  G-Eazy feat. A$AP Rocky & Cardi B          No Limit  2018      1
# ...    ...                                ...               ...   ...    ...
# 1863  1864                   Reezy feat. Nimo            Trance  2020     12
# 1864  1865                           Loredana          Gangster  2020     12
# 1865  1866                          Lil Nas X           Holiday  2020     12
# 1866  1867                     Studio Killers             Jenny  2020     12
# 1867  1868                      Michael Bublé   White Christmas  2020     12
#
# ...

# %%
df3 = pd.read_csv("../../files/csv/audioanalysis_compl.csv")

# %%
df3
# Out:
#       Unnamed: 0    id                             artist             title  \
# 0              0     1              Kollegah & Farid Bang   One Night Stand
# 1              1     2                              Bausa               FML
# 2              2     3                               Jazn            Bombay
# 3              3     4                         Tom Walker  Leave A Light On
# 4              4     5  G-Eazy feat. A$AP Rocky & Cardi B          No Limit
# ...          ...   ...                                ...               ...
# 1863        1863  1864                   Reezy feat. Nimo            Trance
# 1864        1864  1865                           Loredana          Gangster
# 1865        1865  1866                          Lil Nas X           Holiday
# 1866        1866  1867                     Studio Killers             Jenny
# 1867        1867  1868                      Michael Bublé   White Christmas
#
# ...

# %%
df3 = df3[['id', 'genres', 'genre', 'release']]

# %%
df = pd.merge(df, df3, how='left', on=['id'],
                         sort=False)

# %%
df
# Out:
#         id                             artist             title  year  month  \
# 0        1              Kollegah & Farid Bang   One Night Stand  2018      1
# 1        2                              Bausa               FML  2018      1
# 2        3                               Jazn            Bombay  2018      1
# 3        4                         Tom Walker  Leave A Light On  2018      1
# 4        5  G-Eazy feat. A$AP Rocky & Cardi B          No Limit  2018      1
# ...    ...                                ...               ...   ...    ...
# 1863  1864                   Reezy feat. Nimo            Trance  2020     12
# 1864  1865                           Loredana          Gangster  2020     12
# 1865  1866                          Lil Nas X           Holiday  2020     12
# 1866  1867                     Studio Killers             Jenny  2020     12
# 1867  1868                      Michael Bublé   White Christmas  2020     12
#
# ...

# %%
df.to_csv('../../files/csv/overview.csv')

# %%
df.to_pickle('../../files/pickle/overview.pkl')
