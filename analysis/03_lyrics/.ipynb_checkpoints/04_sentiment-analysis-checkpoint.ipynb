# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline 
from collections import Counter
import nltk
import string
# search the text for a word
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.text import Text
from nltk.corpus import stopwords
from tqdm import tqdm

# %%
lyrics = pd.read_csv("../../files/csv/lyricstokenized.csv")
lyrics = lyrics.drop(['Unnamed: 0'], axis=1)

# %%
lyrics
# Out:
#         id                             artist             title  year  \
# 0        1              Kollegah & Farid Bang   One Night Stand  2018
# 1        2                              Bausa               FML  2018
# 2        3                               Jazn            Bombay  2018
# 3        4                         Tom Walker  Leave A Light On  2018
# 4        5  G-Eazy feat. A$AP Rocky & Cardi B          No Limit  2018
# ...    ...                                ...               ...   ...
# 1830  1864                   Reezy feat. Nimo            Trance  2020
# 1831  1865                           Loredana          Gangster  2020
# 1832  1866                          Lil Nas X           Holiday  2020
# 1833  1867                     Studio Killers             Jenny  2020
# 1834  1868                      Michael Bublé   White Christmas  2020
#
#                                                  lyrics lang  \
# 0     Fass' dich an, frag', „Ist die Brust da echt?“...   de
# 1     Ouh-oh-oh-ouh-ouh\nBaby, ich weiß, was du will...   de
# 2     Jajajaja\nOhh, kippe Bombay\nJaja, jaja, ohh\n...   de
# 3     The second someone mentioned you were all alon...   en
# 4     If I hit it one time, I'ma pipe her\nIf I hit ...   en
# ...                                                 ...  ...
# 1830  Ich wart' seit Tagen auf dich, bis du wieder k...   de
# 1831  Miksu\nMacloud\n\nDu sagst, du bist ein Gangst...   de
# 1832  T-T-Tay Keith, Took it to ten (Hey)\n\nAyy, it...   en
# 1833  Jenny, darling, you're my best friend\nBut the...   en
# 1834  I'm dreaming of a white Christmas\nJust like t...   en
#
#                                                   words
# 0     ['fass', 'frag', 'brust', 'echt', 'tanz', 'sch...
# 1     ['ouhohohouhouh', 'baby', 'weiß', 'willst', 'w...
# 2     ['jajajaja', 'ohh', 'kippe', 'bombay', 'jaja',...
# 3     ['second', 'someone', 'mentioned', 'alone', 'c...
# 4     ['hit', 'one', 'time', 'ima', 'pipe', 'hit', '...
# ...                                                 ...
# 1830  ['yeah', 'hes', 'heaven', 'oh', 'yeah', 'youre...
# 1831  ['stahlharter', 'gladiator', 'baller', 'paar',...
# 1832  ['entstanden', 'unendlich', 'langer', 'zeit', ...
# 1833  ['heavy', 'sso', 'shit', 'loyalty', 'royalty',...
# 1834  ['yeah', 'ah', 'kennst', 'einn', 'traum', 'has...
#
# [1835 rows x 7 columns]
