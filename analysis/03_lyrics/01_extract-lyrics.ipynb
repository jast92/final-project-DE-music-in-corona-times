# %%
import pandas as pd
import numpy as np
import time
import lyricsgenius
import getpass
from tqdm import tqdm

# %%
accesstoken = getpass.getpass()
# Out:
# ········

# %%
client_access_token = accesstoken
genius = lyricsgenius.Genius(client_access_token, remove_section_headers=True,
                 skip_non_songs=True, excluded_terms=["Remix", "Live", "Edit", "Mix", "Club"])

# %%
songs = pd.read_csv("../../files/csv/audioanalysis.csv")

# %%
songs
# Out:
#       Unnamed: 0    id                             artist             title  \
# 0              0     1              Kollegah & Farid Bang   One Night Stand
# 1              1     2                              Bausa               FML
# 2              2     3                               Jazn            Bombay
# 3              3     4                         Tom Walker  Leave A Light On
# 4              4     5  G-Eazy feat. A$AP Rocky & Cardi B          No Limit
# ...          ...   ...                                ...               ...
# 1863        1863  1864                   Reezy feat. Nimo            Trance
# 1864        1864  1865                           Loredana          Gangster
# 1865        1865  1866                          Lil Nas X           Holiday
# 1866        1866  1867                     Studio Killers             Jenny
# 1867        1867  1868                      Michael Bublé   White Christmas
#
#       year  month  week  totalweeksincharts  total2018weeksincharts  \
# 0     2018      1     1                   4                       4
# 1     2018      1     1                   7                       7
# 2     2018      1     1                   9                       9
# 3     2018      1     1                  28                      28
# 4     2018      1     1                   5                       5
# ...    ...    ...   ...                 ...                     ...
# 1863  2020     12    49                   1                       0
# 1864  2020     12    49                   1                       0
# 1865  2020     12    49                   1                       0
# 1866  2020     12    49                   1                       0
# 1867  2020     12    49                   1                       0
#
#       total2019weeksincharts  ...  instrumentalness  liveness  valence  \
# 0                          0  ...          0.000000    0.1670    0.309
# 1                          0  ...          0.000309    0.1640    0.246
# 2                          0  ...          0.000167    0.0994    0.422
# 3                          0  ...          0.000002    0.1330    0.267
# 4                          0  ...          0.000000    0.0853    0.405
# ...                      ...  ...               ...       ...      ...
# 1863                       0  ...          0.000052    0.1160    0.692
# 1864                       0  ...          0.000064    0.1360    0.543
# 1865                       0  ...          0.000000    0.0832    0.837
# 1866                       0  ...          0.017800    0.2370    0.540
# 1867                       0  ...          0.000000    0.0721    0.613
#
#         tempo  duration_ms  time_signature              spotify-id  \
# 0     108.883       163773               4  7J82QBqJjwbIDtm1Oxc0uo
# 1     108.589       179718               4  4OwriBNZjK7VtYBxngT3OJ
# 2      96.032       193040               4  083GGYAqJqUkRsy8JyLeyG
# 3      68.976       185863               4  6lOWoTqVnAWXchddtTH31W
# 4     175.957       245387               4  2DQ1ITjI0YoLFzuADN1ZBW
# ...       ...          ...             ...                     ...
# 1863   98.020       166555               4  4ImCq9zxImWzZijKlMyppJ
# 1864  156.104       161582               4  29MYzr6RNOpMY1SijWMGuJ
# 1865  151.947       154998               4  6zFMeegAMYQo0mt8rXtrli
# 1866  133.935       216791               4  2rpVmxAGGc18wpBREaoE0R
# 1867  128.756       204157               4  3aHDEjyb4ZMpdj0G2xDGUM
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7J82QBqJjwbI...
# 1     https://api.spotify.com/v1/tracks/4OwriBNZjK7V...
# 2     https://api.spotify.com/v1/tracks/083GGYAqJqUk...
# 3     https://api.spotify.com/v1/tracks/6lOWoTqVnAWX...
# 4     https://api.spotify.com/v1/tracks/2DQ1ITjI0YoL...
# ...                                                 ...
# 1863  https://api.spotify.com/v1/tracks/4ImCq9zxImWz...
# 1864  https://api.spotify.com/v1/tracks/29MYzr6RNOpM...
# 1865  https://api.spotify.com/v1/tracks/6zFMeegAMYQo...
# 1866  https://api.spotify.com/v1/tracks/2rpVmxAGGc18...
# 1867  https://api.spotify.com/v1/tracks/3aHDEjyb4ZMp...
#
#                                            analysis_url  \
# 0     https://api.spotify.com/v1/audio-analysis/7J82...
# 1     https://api.spotify.com/v1/audio-analysis/4Owr...
# 2     https://api.spotify.com/v1/audio-analysis/083G...
# 3     https://api.spotify.com/v1/audio-analysis/6lOW...
# 4     https://api.spotify.com/v1/audio-analysis/2DQ1...
# ...                                                 ...
# 1863  https://api.spotify.com/v1/audio-analysis/4ImC...
# 1864  https://api.spotify.com/v1/audio-analysis/29MY...
# 1865  https://api.spotify.com/v1/audio-analysis/6zFM...
# 1866  https://api.spotify.com/v1/audio-analysis/2rpV...
# 1867  https://api.spotify.com/v1/audio-analysis/3aHD...
#
#                                        uri
# 0     spotify:track:7J82QBqJjwbIDtm1Oxc0uo
# 1     spotify:track:4OwriBNZjK7VtYBxngT3OJ
# 2     spotify:track:083GGYAqJqUkRsy8JyLeyG
# 3     spotify:track:6lOWoTqVnAWXchddtTH31W
# 4     spotify:track:2DQ1ITjI0YoLFzuADN1ZBW
# ...                                    ...
# 1863  spotify:track:4ImCq9zxImWzZijKlMyppJ
# 1864  spotify:track:29MYzr6RNOpMY1SijWMGuJ
# 1865  spotify:track:6zFMeegAMYQo0mt8rXtrli
# 1866  spotify:track:2rpVmxAGGc18wpBREaoE0R
# 1867  spotify:track:3aHDEjyb4ZMpdj0G2xDGUM
#
# [1868 rows x 28 columns]

# %%
artisttweaked = [a.split(" feat. ")[0].split(" x ")[0].replace(" & ", " ").replace(" / ", " ").replace("'", "").replace(" [DE]", "").replace(".", " ").replace("?", "").replace("¿", "").replace(" +", "").replace(" [UK]", "").replace(" [2019]", "").replace(" [Live]", "") for a in songs['artist']]
titletweaked = [t.split(" feat. ")[0].split(" x ")[0].replace(" & ", " ").replace(" / ", " ").replace("'", " ").replace(" [DE]", "").replace(".", " ").replace("?", "").replace("¿", "").replace(" +", "").replace(" [UK]", "").replace(" [2019]", "").replace(" [Live]", "") for t in songs['title']]

searchterms = []
for a, t in zip(artisttweaked, titletweaked):
    s = a + " " + t
    searchterms.append(s)

# %%
lyrics = []

for searchy in tqdm(searchterms):
    try:
        songsind = genius.search_songs(searchy)
        url = songsind['hits'][0]['result']['url']
        song_lyrics = genius.lyrics(url)
        lyrics.append(song_lyrics)
    except:
        lyrics.append(np.nan)
# Out:
#  78%|███████████████████████████████████████████████████████████▏                | 1454/1868 [1:13:29<14:46,  2.14s/it]
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Vicetone-and-tony-igy-astronomia-lyrics
#  85%|████████████████████████████████████████████████████████████████▎           | 1582/1868 [1:19:20<12:07,  2.54s/it]
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Conkarah-banana-dave-aude-remix-lyrics
#  93%|██████████████████████████████████████████████████████████████████████▎     | 1729/1868 [1:25:43<05:49,  2.52s/it]
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Clean-bandit-and-mabel-tick-tock-joel-corry-remix-lyrics
# 100%|████████████████████████████████████████████████████████████████████████████| 1868/1868 [1:31:34<00:00,  2.94s/it]

# %%
lyrics.count(np.nan)
# Out:
# 30

# %%
len(lyrics)
# Out:
# 1868

# %%
songs['lyrics'] = lyrics

# %%
songs.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'id',
#  'artist',
#  'title',
#  'year',
#  'month',
#  'week',
#  'totalweeksincharts',
#  'total2018weeksincharts',
#  'total2019weeksincharts',
#  'total2020weeksincharts',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'spotify-id',
#  'track_href',
#  'analysis_url',
#  'uri',
#  'lyrics']

# %%
songs[['id', 'artist', 'title', 'year', 'month', 'week', 'totalweeksincharts', 'total2018weeksincharts', 'total2019weeksincharts', 'total2020weeksincharts', 'lyrics']].to_csv("../../files/csv/lyrics.csv")
songs[['id', 'artist', 'title', 'year', 'month', 'week', 'totalweeksincharts', 'total2018weeksincharts', 'total2019weeksincharts', 'total2020weeksincharts', 'lyrics']].to_pickle("../../files/pickle/lyrics.pkl")

# %%
lang
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
songs['lyrics'].nunique()
# Out:
# 51
